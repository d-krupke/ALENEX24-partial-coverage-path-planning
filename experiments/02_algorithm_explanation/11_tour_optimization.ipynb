# %%
import matplotlib.pyplot as plt

figsize = (3.5, 3)

# %%
from pcpptc import PolygonInstance
from shapely.geometry import Polygon, Point


area = Polygon(
    shell=[
        Point(5.0, 5.0),
        Point(4.0, 12.0),
        Point(0.0, 9.0),
        Point(0.0, 13.0),
        Point(3.0, 15.0),
        Point(10.0, 15.0),
        Point(15.0, 14.0),
        Point(17.0, 6.0),
        Point(11.0, 6.5),
        Point(11.0, 10.0),
        Point(10.0, 12.0),
        Point(9.0, 12.0),
        Point(10.0, 10.0),
        Point(10.0, 4.0),
    ][::-1]
)
area = Polygon(
    shell=[
        Point(9.0, 18.0),
        Point(1.0, 16.0),
        Point(0.0, 9.0),
        Point(4.0, 8.0),
        Point(4.0, 13.0),
        Point(8.0, 12.0),
        Point(5.0, 7.0),
        Point(5.0, 2.0),
        Point(12.0, 1.0),
        Point(14.0, 6.0),
        Point(12.0, 10.0),
        Point(13.0, 12.0),
        Point(19.0, 11.0),
        Point(21.0, 14.0),
        Point(18.0, 17.0),
    ],
)
# holes=[[(13.0, 16.0), (11.0, 13.0), (10.0, 14.0)]])
valuable_areas = [
    [
        Polygon(
            shell=[Point(0.0, 14.0), Point(0.0, 8.0), Point(4.0, 8.0), Point(4.0, 13.0)]
        ),
        130.0,
    ],
    [
        Polygon(
            shell=[
                Point(6.0, 3.0),
                Point(14.0, 2.0),
                Point(15.0, 10.0),
                Point(6.0, 6.0),
            ]
        ),
        130.0,
    ],
    [
        Polygon(
            shell=[
                Point(15.0, 11.0),
                Point(21.0, 10.0),
                Point(22.0, 16.0),
                Point(14.0, 16.0),
            ]
        ),
        130.0,
    ],
]
for i, (poly, val) in enumerate(valuable_areas):
    poly = poly.intersection(area)
    valuable_areas[i][0] = poly


# valuable_area = Polygon(shell=[Point(0.0, 0.0), Point(0.0, 15.0), Point(2.0, 17.0), Point(3.0, 10.0), Point(16.0, 8.0), Point(16.0, 0.0)])

# valuable_areas = list(area.intersection(valuable_area))
# assert len(valuable_areas)==2

# valuable_areas = [(valuable_areas[0], 130.0),
#                 (valuable_areas[1], 130.0),
#                (valuable_areas[2], 130.0)]
pi = PolygonInstance(
    feasible_area=area.buffer(-0.5),
    tool_radius=0.5,
    original_area=area,
    valuable_areas=valuable_areas,
    turn_cost=25.0,
    distance_cost=10.0,
)

# %%
from pcpptc.plot import setup_plot, plot_polygon_instance

ax = setup_plot()
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plt.show()

# %%
from pcpptc.instance_converter.dmsh import DmshGrid

gi = DmshGrid(full_coverage=False, point_based=False, buffer=0.1)(pi)
# Out:
# Numerical problems for Voronoi-cell of PointVertex[140329850752400]@(6.529363554382531, 16.815413865073204). Using workaround.
# Warning: Voronoi cell at PointVertex[140329850752400]@(6.529363554382531, 16.815413865073204) unexpected large (4.512743595203892. Replacing with workaround
# Numerical problems for Voronoi-cell of PointVertex[140329850766160]@(7.794039457356742, 17.13158284081676). Using workaround.
# Warning: Voronoi cell at PointVertex[140329850766160]@(7.794039457356742, 17.13158284081676) unexpected large (4.649426829467124. Replacing with workaround
# Warning: Voronoi cell at PointVertex[140329857885840]@(9.03750196483885, 17.442448467687285) unexpected large (82.90130369935422. Replacing with workaround
# Warning: Voronoi cell at PointVertex[140329851121040]@(1.4921718922968272, 15.55611594955178) unexpected large (56.21402968702413. Replacing with workaround
# Numerical problems for Voronoi-cell of PointVertex[140329850750224]@(2.8034921395355576, 15.883946011361463). Using workaround.
# Warning: Voronoi cell at PointVertex[140329850750224]@(2.8034921395355576, 15.883946011361463) unexpected large (4.820655356054856. Replacing with workaround
# Numerical problems for Voronoi-cell of PointVertex[140329850752144]@(4.125163769867481, 16.214363918944443). Using workaround.
# Warning: Voronoi cell at PointVertex[140329850752144]@(4.125163769867481, 16.214363918944443) unexpected large (4.517049723860201. Replacing with workaround
# Numerical problems for Voronoi-cell of PointVertex[140329850752272]@(5.328648068078851, 16.515234993497288). Using workaround.
# Warning: Voronoi cell at PointVertex[140329850752272]@(5.328648068078851, 16.515234993497288) unexpected large (4.344407661070161. Replacing with workaround

# %%
from pcpptc.plot.intermediate import plot_graph

ax = setup_plot()
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plot_graph(ax, gi.graph)

valuable_points = [
    v for v in gi.graph.nodes if gi.coverage_necessities[v].penalty_vector
]
plt.scatter([v.x for v in valuable_points], [v.y for v in valuable_points], zorder=3)

# %%
from pcpptc.plot import plot_solution
from pcpptc.grid_solver.cycle_cover.solver import CycleCoverSolver

cc = CycleCoverSolver(k=3, r=2)(gi)
ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plot_graph(ax, gi.graph, marker=".", vertex_color="grey", edge_color="grey")
for tour in cc:
    plot_solution(ax, tour.waypoints(), color="blue", w=2)
plt.tight_layout()
plt.show()
# Out:
# Cycle Cover: Computing fractional solution...
# Academic license - for non-commercial use only - expires 2021-09-25
# Using license file /home/ANONYMOUS_USER/gurobi.lic
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 502 rows, 2726 columns and 5919 nonzeros
# Model fingerprint: 0x28a60b7f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 502 rows, 2666 columns, 5859 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.700000e+01   0.000000e+00      0s
#      414    2.0167270e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 414 iterations and 0.02 seconds
# Optimal objective  2.016727012e+03
# Cycle Cover: Creating matching problem...
# Cycle Cover: Solving matching...
# Solve matching on 60744 edges.

# %%
from pcpptc.grid_solver.cycle_connecting import connect_cycles_via_pcst

tour = connect_cycles_via_pcst(gi, cc)

ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plot_graph(ax, gi.graph, marker=".", vertex_color="grey", edge_color="grey")
plot_solution(ax, tour.waypoints(), color="blue", w=2)
plt.tight_layout()
plt.show()
# Out:
# Connecting 6 cycles
# Trying to connect greedily
# 6 cycles remaining
# Computing PCST
# Connecting PCST via DFS

# %%
from pcpptc.plot.intermediate import plot_fractional_solution
from pcpptc.grid_solver.grid_solution import FractionalSolution

tour = connect_cycles_via_pcst(gi, cc)
frac_sol = tour.to_fractional_solution()
redundant_frac_sol = FractionalSolution()
for v in frac_sol.vertices():
    if sum(frac_sol.at_vertex(v).values()) > 1.0:
        for vp, val in frac_sol.at_vertex(v).items():
            redundant_frac_sol[vp] = val
ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plot_graph(ax, gi.graph, marker=".", vertex_color="grey", edge_color="grey")
plot_solution(ax, tour.waypoints(), color="blue", w=2)
plot_fractional_solution(ax, redundant_frac_sol, color="red", linewidth=2, zorder=3)
plt.tight_layout()
plt.show()
# Out:
# Connecting 6 cycles
# Trying to connect greedily
# 6 cycles remaining
# Computing PCST
# Connecting PCST via DFS

# %%
from pcpptc.grid_solver.grid_solution import create_cycle_solution
from pcpptc.grid_solver.cycle_cover.lns.lns import TourLns

tour = connect_cycles_via_pcst(gi, cc)
frac_sol = tour.to_fractional_solution()
tr = TourLns(20, 20)
sol = tr.optimize(gi, frac_sol)
tour = create_cycle_solution(gi.graph, sol)[0]
ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi, plot_valuable_areas=True)
plot_graph(ax, gi.graph, marker=".", vertex_color="grey", edge_color="grey")
plot_solution(ax, tour.waypoints(), color="blue", w=2)
plt.tight_layout()
plt.savefig("11_optimized.pdf")
plt.show()
# Out:
# Connecting 6 cycles
# Trying to connect greedily
# 6 cycles remaining
# Computing PCST
# Connecting PCST via DFS
# Optimize tour around PointVertex[140329850749584]@(16.867426300601167, 14.32869933551367).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 308 columns and 785 nonzeros
# Model fingerprint: 0x8d7809eb
# Variable types: 0 continuous, 308 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 680.14
#
# Presolve removed 2 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 69 rows, 304 columns, 761 nonzeros
# Variable types: 0 continuous, 304 integer (26 binary)
#
# Root relaxation: objective 5.442701e+02, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  544.27006    0   35  680.14012  544.27006  20.0%     -    0s
# H    0     0                     606.7510708  544.27006  10.3%     -    0s
#      0     0  562.72207    0   49  606.75107  562.72207  7.26%     -    0s
#      0     0  562.72207    0   35  606.75107  562.72207  7.26%     -    0s
#      0     0  572.91353    0   47  606.75107  572.91353  5.58%     -    0s
# H    0     0                     601.5677780  581.16940  3.39%     -    0s
#      0     0  601.56778    0   45  601.56778  601.56778  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 1
#   Zero half: 17
#
# Explored 1 nodes (231 simplex iterations) in 0.07 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 601.568 606.751 680.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.015677779903e+02, best bound 6.015677779903e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850723856]@(2.2448107124834094, 12.398755548699917).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 61 rows, 261 columns and 622 nonzeros
# Model fingerprint: 0x25b588b4
# Variable types: 0 continuous, 261 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 568.846
#
# Presolve removed 2 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 257 columns, 598 nonzeros
# Variable types: 0 continuous, 257 integer (15 binary)
#
# Root relaxation: objective 4.011279e+02, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  401.12794    0    7  568.84619  401.12794  29.5%     -    0s
# H    0     0                     543.3892813  401.12794  26.2%     -    0s
#      0     0  428.57777    0   10  543.38928  428.57777  21.1%     -    0s
# H    0     0                     473.8602933  428.57777  9.56%     -    0s
#      0     0  446.05823    0   12  473.86029  446.05823  5.87%     -    0s
#      0     0     cutoff    0       473.86029  473.86029  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 473.86 543.389 568.846
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.738602932973e+02, best bound 4.738602932973e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850720912]@(11.721698040786183, 6.9457024383108426).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 307 columns and 778 nonzeros
# Model fingerprint: 0x75129ca1
# Variable types: 0 continuous, 307 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 701.173
#
# Presolve removed 4 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 299 columns, 730 nonzeros
# Variable types: 0 continuous, 299 integer (29 binary)
#
# Root relaxation: objective 4.929414e+02, 66 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  492.94142    0   41  701.17290  492.94142  29.7%     -    0s
#      0     0  529.68841    0   58  701.17290  529.68841  24.5%     -    0s
# H    0     0                     633.3769879  529.68841  16.4%     -    0s
#      0     0  530.90336    0   50  633.37699  530.90336  16.2%     -    0s
#      0     0  537.06621    0   58  633.37699  537.06621  15.2%     -    0s
#      0     0  539.35931    0   65  633.37699  539.35931  14.8%     -    0s
#      0     0  540.08114    0   58  633.37699  540.08114  14.7%     -    0s
#      0     0  540.36732    0   66  633.37699  540.36732  14.7%     -    0s
# H    0     0                     627.6005234  540.36732  13.9%     -    0s
# H    0     0                     591.4031628  540.36732  8.63%     -    0s
#      0     0  542.73308    0   63  591.40316  542.73308  8.23%     -    0s
#      0     0  542.73308    0   40  591.40316  542.73308  8.23%     -    0s
#      0     0  542.73308    0   41  591.40316  542.73308  8.23%     -    0s
# H    0     0                     553.9302505  542.73308  2.02%     -    0s
#      0     0  542.73308    0   54  553.93025  542.73308  2.02%     -    0s
#      0     0  542.73308    0   63  553.93025  542.73308  2.02%     -    0s
#      0     0  542.73308    0   61  553.93025  542.73308  2.02%     -    0s
#      0     0  544.60769    0   66  553.93025  544.60769  1.68%     -    0s
#      0     0  544.60769    0   41  553.93025  544.60769  1.68%     -    0s
# H    0     0                     549.7535942  544.60769  0.94%     -    0s
#      0     0  549.75359    0   50  549.75359  549.75359  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   Zero half: 18
#   RLT: 1
#
# Explored 1 nodes (436 simplex iterations) in 0.13 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 549.754 553.93 591.403 ... 701.173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.497535942165e+02, best bound 5.497535942165e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 73 rows, 307 columns and 930 nonzeros
# Model fingerprint: 0x3de806e1
# Variable types: 0 continuous, 307 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 701.173
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R71 by 1.000000000
#
# Presolve removed 4 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 69 rows, 299 columns, 880 nonzeros
# Variable types: 0 continuous, 299 integer (29 binary)
#
# Root relaxation: objective 4.929414e+02, 67 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  492.94142    0   41  701.17290  492.94142  29.7%     -    0s
#      0     0  529.68841    0   58  701.17290  529.68841  24.5%     -    0s
# H    0     0                     633.3769879  529.68841  16.4%     -    0s
#      0     0  530.90336    0   50  633.37699  530.90336  16.2%     -    0s
#      0     0  536.67082    0   63  633.37699  536.67082  15.3%     -    0s
#      0     0  538.66078    0   66  633.37699  538.66078  15.0%     -    0s
#      0     0  540.02750    0   56  633.37699  540.02750  14.7%     -    0s
#      0     0  540.19733    0   66  633.37699  540.19733  14.7%     -    0s
#      0     0  540.23045    0   54  633.37699  540.23045  14.7%     -    0s
# H    0     0                     627.6005234  540.23045  13.9%     -    0s
# H    0     0                     591.4031628  540.23045  8.65%     -    0s
#      0     0  542.44315    0   58  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   41  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   44  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   63  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   57  591.40316  542.44315  8.28%     -    0s
# H    0     0                     555.1612419  542.44315  2.29%     -    0s
#      0     0  542.44315    0   52  555.16124  542.44315  2.29%     -    0s
#      0     0  542.44315    0   59  555.16124  542.44315  2.29%     -    0s
#      0     0  543.18244    0   67  555.16124  543.18244  2.16%     -    0s
#      0     0  543.18244    0   21  555.16124  543.18244  2.16%     -    0s
# *    0     0               0     553.9302505  553.93025  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 5
#
# Explored 1 nodes (467 simplex iterations) in 0.13 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 553.93 555.161 591.403 ... 701.173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.539302505080e+02, best bound 5.539302505080e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850710864]@(10.402417084692415, 4.891181011186349).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 83 rows, 340 columns and 874 nonzeros
# Model fingerprint: 0x4bd20e45
# Variable types: 0 continuous, 340 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 486.448
#
# Presolve removed 15 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 320 columns, 734 nonzeros
# Variable types: 0 continuous, 320 integer (45 binary)
#
# Root relaxation: objective 4.322638e+02, 68 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  432.26375    0   45  486.44767  432.26375  11.1%     -    0s
# H    0     0                     482.2710154  442.75569  8.19%     -    0s
#      0     0  458.74964    0   61  482.27102  458.74964  4.88%     -    0s
#      0     0  458.74964    0   37  482.27102  458.74964  4.88%     -    0s
#      0     0  482.27102    0   49  482.27102  482.27102  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 8
#
# Explored 1 nodes (175 simplex iterations) in 0.04 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 482.271 486.448
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.822710154259e+02, best bound 4.822710154259e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 85 rows, 340 columns and 1032 nonzeros
# Model fingerprint: 0x9af8f896
# Variable types: 0 continuous, 340 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 486.448
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R83 by 1.000000000
#
# Presolve removed 15 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 70 rows, 320 columns, 890 nonzeros
# Variable types: 0 continuous, 320 integer (45 binary)
#
# Root relaxation: objective 4.322638e+02, 68 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  432.26375    0   45  486.44767  432.26375  11.1%     -    0s
#      0     0  457.93151    0   61  486.44767  457.93151  5.86%     -    0s
#      0     0  457.93151    0   38  486.44767  457.93151  5.86%     -    0s
#      0     0  458.19525    0   51  486.44767  458.19525  5.81%     -    0s
#      0     0  467.20444    0   50  486.44767  467.20444  3.96%     -    0s
# H    0     0                     484.2043074  467.20444  3.51%     -    0s
#      0     0  469.43894    0   50  484.20431  469.43894  3.05%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 3
#   GUB cover: 1
#   Zero half: 11
#
# Explored 1 nodes (201 simplex iterations) in 0.07 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 484.204 486.448
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.842043073588e+02, best bound 4.842043073588e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850749840]@(18.922018638506028, 13.766873054511441).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 302 columns and 769 nonzeros
# Model fingerprint: 0xe7356a3d
# Variable types: 0 continuous, 302 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 622.187
#
# Presolve removed 8 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 298 columns, 740 nonzeros
# Variable types: 0 continuous, 298 integer (27 binary)
#
# Root relaxation: objective 5.766232e+02, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  576.62317    0   35  622.18733  576.62317  7.32%     -    0s
#      0     0  599.73956    0   30  622.18733  599.73956  3.61%     -    0s
#      0     0  599.73956    0   29  622.18733  599.73956  3.61%     -    0s
#      0     0     cutoff    0       622.18733  622.18733  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Cover: 2
#   MIR: 2
#   Zero half: 9
#
# Explored 1 nodes (179 simplex iterations) in 0.05 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 622.187
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.221873250970e+02, best bound 6.221873250970e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850734928]@(15.077489302267177, 13.296239996551405).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 69 rows, 302 columns and 709 nonzeros
# Model fingerprint: 0xfb229cf3
# Variable types: 0 continuous, 302 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 454.735
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 293 columns, 653 nonzeros
# Variable types: 0 continuous, 293 integer (24 binary)
#
# Root relaxation: objective 3.837629e+02, 47 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     383.7629015  383.76290  0.00%     -    0s
#
# Explored 0 nodes (47 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 383.763 454.735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.837629015052e+02, best bound 3.837629015052e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 302 columns and 833 nonzeros
# Model fingerprint: 0xe16f10d6
# Variable types: 0 continuous, 302 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 454.735
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R69 by 2.000000000
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 63 rows, 293 columns, 774 nonzeros
# Variable types: 0 continuous, 293 integer (24 binary)
#
# Root relaxation: objective 3.879672e+02, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  387.96719    0   19  454.73487  387.96719  14.7%     -    0s
# H    0     0                     444.0882829  387.96719  12.6%     -    0s
# H    0     0                     410.2704797  387.96719  5.44%     -    0s
# H    0     0                     393.0265096  387.96719  1.29%     -    0s
# H    0     0                     390.5233470  387.96719  0.65%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   Zero half: 1
#
# Explored 1 nodes (58 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 390.523 393.027 410.27 ... 454.735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.905233469657e+02, best bound 3.905233469657e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850720656]@(9.380039438154913, 7.080127466299323).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 75 rows, 308 columns and 737 nonzeros
# Model fingerprint: 0x39fe7a67
# Variable types: 0 continuous, 308 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 465.004
#
# Presolve removed 15 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 295 columns, 646 nonzeros
# Variable types: 0 continuous, 295 integer (29 binary)
#
# Root relaxation: objective 4.193286e+02, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  419.32863    0   30  465.00438  419.32863  9.82%     -    0s
# H    0     0                     453.2982146  420.79734  7.17%     -    0s
#      0     0  433.98211    0   31  453.29821  433.98211  4.26%     -    0s
# *    0     0               0     449.0383305  449.03833  0.00%     -    0s
#
# Explored 1 nodes (103 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 449.038 453.298 465.004
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.490383304907e+02, best bound 4.490383304907e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850709712]@(6.859258434638642, 4.330752520800434).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 302 columns and 763 nonzeros
# Model fingerprint: 0x1828d63d
# Variable types: 0 continuous, 302 integer (19 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 362.82
#
# Presolve removed 11 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 294 columns, 705 nonzeros
# Variable types: 0 continuous, 294 integer (29 binary)
#
# Root relaxation: objective 3.626506e+02, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       362.82032  362.82032  0.00%     -    0s
#
# Explored 0 nodes (56 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 362.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.628203196584e+02, best bound 3.628203196584e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850734544]@(11.780238183522124, 13.26259715481488).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 58 rows, 278 columns and 485 nonzeros
# Model fingerprint: 0x3d269cea
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
#
# Presolve removed 9 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 273 columns, 463 nonzeros
# Variable types: 0 continuous, 273 integer (7 binary)
#
# Root relaxation: objective 2.689890e+02, 21 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     268.9889529  268.98895  0.00%     -    0s
#
# Explored 0 nodes (21 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 268.989 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.689889529064e+02, best bound 2.689889529064e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 60 rows, 278 columns and 534 nonzeros
# Model fingerprint: 0x2da95d52
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R58 by 1.000000000
#
# Presolve removed 10 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 272 columns, 507 nonzeros
# Variable types: 0 continuous, 272 integer (6 binary)
#
# Root relaxation: objective 3.017281e+02, 25 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  301.72807    0   10  347.89941  301.72807  13.3%     -    0s
# H    0     0                     346.0396985  301.72807  12.8%     -    0s
# H    0     0                     336.3634743  301.72807  10.3%     -    0s
# H    0     0                     304.4639641  301.72807  0.90%     -    0s
#
# Explored 1 nodes (25 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 304.464 336.363 346.04 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044639641132e+02, best bound 3.044639641132e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 3 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 63 rows, 278 columns and 562 nonzeros
# Model fingerprint: 0x9d4e87fd
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R60 by 2.000000000
#
# Presolve removed 11 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 271 columns, 527 nonzeros
# Variable types: 0 continuous, 271 integer (5 binary)
#
# Root relaxation: objective 3.088107e+02, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  310.51342    0   13  347.89941  310.51342  10.7%     -    0s
# H    0     0                     316.2740426  310.51342  1.82%     -    0s
#      0     0  310.51342    0   13  316.27404  310.51342  1.82%     -    0s
#
# Explored 1 nodes (29 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 316.274 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.162740425746e+02, best bound 3.162740425746e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850711376]@(7.561772039668687, 6.3301042491376665).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 80 rows, 307 columns and 730 nonzeros
# Model fingerprint: 0xde9f9037
# Variable types: 0 continuous, 307 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 435.442
#
# Presolve removed 19 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 295 columns, 661 nonzeros
# Variable types: 0 continuous, 295 integer (28 binary)
#
# Root relaxation: objective 4.352728e+02, 70 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       435.44248  435.44248  0.00%     -    0s
#
# Explored 0 nodes (70 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 435.442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.354424818767e+02, best bound 4.354424818767e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850722832]@(3.450661739619864, 9.808861413176789).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 62 rows, 252 columns and 608 nonzeros
# Model fingerprint: 0xbed957e3
# Variable types: 0 continuous, 252 integer (11 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 529.773
#
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 252 columns, 608 nonzeros
# Variable types: 0 continuous, 252 integer (12 binary)
#
# Root relaxation: objective 4.570408e+02, 44 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  457.04081    0    7  529.77317  457.04081  13.7%     -    0s
#      0     0  477.03739    0    8  529.77317  477.03739  10.0%     -    0s
#      0     0  477.03739    0    6  529.77317  477.03739  10.0%     -    0s
#      0     0     cutoff    0       529.77317  529.77317  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 1
#   Zero half: 2
#
# Explored 1 nodes (91 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 529.773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.297731695401e+02, best bound 5.297731695401e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329851120528]@(3.5491912569691024, 13.314972840739191).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 57 rows, 279 columns and 568 nonzeros
# Model fingerprint: 0xa1962c08
# Variable types: 0 continuous, 279 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 319.118
#
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 277 columns, 546 nonzeros
# Variable types: 0 continuous, 277 integer (13 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       319.11779  319.11779  0.00%     -    0s
#
# Explored 0 nodes (33 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 319.118
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.191177885133e+02, best bound 3.191177885133e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850752016]@(18.555063203446714, 15.667119337248085).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 296 columns and 751 nonzeros
# Model fingerprint: 0xba467f61
# Variable types: 0 continuous, 296 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 494.919
#
# Presolve removed 12 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 64 rows, 287 columns, 695 nonzeros
# Variable types: 0 continuous, 287 integer (28 binary)
#
# Root relaxation: objective 4.507433e+02, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  450.74335    0   27  494.91946  450.74335  8.93%     -    0s
#      0     0  482.73380    0   28  494.91946  482.73380  2.46%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (78 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 494.919
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.949194600656e+02, best bound 4.949194600656e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850766672]@(0.7883485356521597, 10.629352453039107).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 66 rows, 252 columns and 608 nonzeros
# Model fingerprint: 0xe47b5f25
# Variable types: 0 continuous, 252 integer (11 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 529.773
#
# Presolve removed 6 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 252 columns, 608 nonzeros
# Variable types: 0 continuous, 252 integer (12 binary)
#
# Root relaxation: objective 4.570408e+02, 46 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  457.04081    0    7  529.77317  457.04081  13.7%     -    0s
#      0     0  477.03739    0   10  529.77317  477.03739  10.0%     -    0s
#      0     0     cutoff    0       529.77317  529.77317  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 529.773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.297731695401e+02, best bound 5.297731695401e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850749200]@(13.83963526377084, 14.691667640449392).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 73 rows, 304 columns and 662 nonzeros
# Model fingerprint: 0xb08464d3
# Variable types: 0 continuous, 304 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 308.304
#
# Presolve removed 16 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 293 columns, 600 nonzeros
# Variable types: 0 continuous, 293 integer (25 binary)
#
# Root relaxation: objective 2.938443e+02, 42 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     293.8443348  293.84433  0.00%     -    0s
#
# Explored 0 nodes (42 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 293.844 308.304
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.938443347599e+02, best bound 2.938443347599e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 75 rows, 304 columns and 772 nonzeros
# Model fingerprint: 0x3ee117da
# Variable types: 0 continuous, 304 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 308.304
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R73 by 1.000000000
#
# Presolve removed 16 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 293 columns, 704 nonzeros
# Variable types: 0 continuous, 293 integer (25 binary)
#
# Root relaxation: objective 3.010741e+02, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  304.07238    0   10  308.30395  304.07238  1.37%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (53 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 308.304
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.083039462268e+02, best bound 3.083039462268e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850708560]@(11.015224261353866, 2.8014162578668507).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 82 rows, 316 columns and 804 nonzeros
# Model fingerprint: 0xb8777a03
# Variable types: 0 continuous, 316 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [8e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 373.575
#
# Presolve removed 17 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 303 columns, 713 nonzeros
# Variable types: 0 continuous, 303 integer (34 binary)
#
# Root relaxation: cutoff, 38 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       373.57468  373.57468  0.00%     -    0s
#
# Explored 0 nodes (38 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 373.575
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.735746783362e+02, best bound 3.735746783362e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850722448]@(10.742012801935333, 8.998425668654535).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 72 rows, 291 columns and 610 nonzeros
# Model fingerprint: 0xd1b6904f
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
#
# Presolve removed 15 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 281 columns, 560 nonzeros
# Variable types: 0 continuous, 281 integer (23 binary)
#
# Root relaxation: objective 3.599007e+02, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     359.9006725  359.90067  0.00%     -    0s
#
# Explored 0 nodes (48 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 359.901 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.599006725172e+02, best bound 3.599006725172e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 74 rows, 291 columns and 686 nonzeros
# Model fingerprint: 0x861de559
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R72 by 1.000000000
#
# Presolve removed 18 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 277 columns, 621 nonzeros
# Variable types: 0 continuous, 277 integer (18 binary)
#
# Root relaxation: objective 3.953456e+02, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  395.34561    0   25  431.93750  395.34561  8.47%     -    0s
# H    0     0                     413.1938524  395.34561  4.32%     -    0s
#      0     0     cutoff    0       413.19385  413.19385  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (53 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 413.194 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.131938524474e+02, best bound 4.131938524474e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 291 columns and 779 nonzeros
# Model fingerprint: 0xb5a36801
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R74 by 1.000000000
#
# Presolve removed 18 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 277 columns, 710 nonzeros
# Variable types: 0 continuous, 277 integer (18 binary)
#
# Root relaxation: objective 3.953456e+02, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  395.34561    0   25  431.93750  395.34561  8.47%     -    0s
# *    0     0               0     414.5672949  414.56729  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 1
#   Zero half: 5
#
# Explored 1 nodes (63 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 414.567 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.145672949195e+02, best bound 4.145672949195e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850723600]@(10.899309734342483, 11.144536799566804).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 68 rows, 289 columns and 495 nonzeros
# Model fingerprint: 0xdd44c0ed
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 282 columns, 471 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.433159e+02, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     243.3159220  243.31592  0.00%     -    0s
#
# Explored 0 nodes (18 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 243.316 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.433159219869e+02, best bound 2.433159219869e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 70 rows, 289 columns and 556 nonzeros
# Model fingerprint: 0x58482bce
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R68 by 1.000000000
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 282 columns, 531 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.565171e+02, 26 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  256.51706    0    6  337.09271  256.51706  23.9%     -    0s
# H    0     0                     278.9055543  256.51706  8.03%     -    0s
#      0     0  266.33935    0    7  278.90555  266.33935  4.51%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 1
#
# Explored 1 nodes (30 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 278.906 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.789055543438e+02, best bound 2.789055543438e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 72 rows, 289 columns and 618 nonzeros
# Model fingerprint: 0x7c208b1d
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R70 by 2.000000000
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 282 columns, 593 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.565171e+02, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  256.51706    0    6  337.09271  256.51706  23.9%     -    0s
# H    0     0                     292.6971391  256.51706  12.4%     -    0s
#      0     0  270.93654    0   19  292.69714  270.93654  7.43%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 1
#
# Explored 1 nodes (34 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 292.697 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.926971390551e+02, best bound 2.926971390551e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850724112]@(9.516861784299248, 12.361285732935182).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 59 rows, 257 columns and 425 nonzeros
# Model fingerprint: 0xbdab340a
# Variable types: 0 continuous, 257 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 222.64
#
# Presolve removed 13 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 254 columns, 422 nonzeros
# Variable types: 0 continuous, 254 integer (7 binary)
#
# Root relaxation: objective 1.811143e+02, 16 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     181.1143392  181.11434  0.00%     -    0s
#
# Explored 0 nodes (16 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 181.114 222.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.811143391763e+02, best bound 1.811143391763e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 61 rows, 257 columns and 451 nonzeros
# Model fingerprint: 0x3116f0ab
# Variable types: 0 continuous, 257 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 222.64
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R59 by 1.000000000
#
# Presolve removed 15 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 252 columns, 440 nonzeros
# Variable types: 0 continuous, 252 integer (6 binary)
#
# Root relaxation: objective 2.134332e+02, 23 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       222.63981  222.63981  0.00%     -    0s
#
# Explored 0 nodes (23 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 222.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.226398118404e+02, best bound 2.226398118404e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850710352]@(5.55, 5.765491662848854).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 289 columns and 682 nonzeros
# Model fingerprint: 0xd766ac3a
# Variable types: 0 continuous, 289 integer (14 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 357.358
#
# Presolve removed 17 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 281 columns, 624 nonzeros
# Variable types: 0 continuous, 281 integer (24 binary)
#
# Root relaxation: objective 3.571882e+02, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       357.35797  357.35797  0.00%     -    0s
#
# Explored 0 nodes (55 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 357.358
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.573579675195e+02, best bound 3.573579675195e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.

# %%
from pcpptc.grid_solver.grid_solution import create_cycle_solution
from pcpptc.grid_solver.cycle_cover.lns.lns import TourLns

tour = connect_cycles_via_pcst(gi, cc)
frac_sol = tour.to_fractional_solution()


def enumerate_solution(n):
    tr = TourLns(20, repetitions=n)
    sol = frac_sol
    yield [], sol
    for root, area, sol in tr.continous_optimization(gi, sol):
        yield area, sol
        if n < 0:
            break
        n -= 1


solutions = [(A, sol) for A, sol in enumerate_solution(20)]
# Out:
# Connecting 6 cycles
# Trying to connect greedily
# 6 cycles remaining
# Computing PCST
# Connecting PCST via DFS
# Optimize tour around PointVertex[140329850749584]@(16.867426300601167, 14.32869933551367).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 308 columns and 785 nonzeros
# Model fingerprint: 0x8d7809eb
# Variable types: 0 continuous, 308 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 680.14
#
# Presolve removed 2 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 69 rows, 304 columns, 761 nonzeros
# Variable types: 0 continuous, 304 integer (26 binary)
#
# Root relaxation: objective 5.442701e+02, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  544.27006    0   35  680.14012  544.27006  20.0%     -    0s
# H    0     0                     606.7510708  544.27006  10.3%     -    0s
#      0     0  562.72207    0   49  606.75107  562.72207  7.26%     -    0s
#      0     0  562.72207    0   35  606.75107  562.72207  7.26%     -    0s
#      0     0  572.91353    0   47  606.75107  572.91353  5.58%     -    0s
# H    0     0                     601.5677780  581.16940  3.39%     -    0s
#      0     0  601.56778    0   45  601.56778  601.56778  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 1
#   Zero half: 17
#
# Explored 1 nodes (231 simplex iterations) in 0.07 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 601.568 606.751 680.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.015677779903e+02, best bound 6.015677779903e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850723856]@(2.2448107124834094, 12.398755548699917).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 61 rows, 261 columns and 622 nonzeros
# Model fingerprint: 0x25b588b4
# Variable types: 0 continuous, 261 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 568.846
#
# Presolve removed 2 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 257 columns, 598 nonzeros
# Variable types: 0 continuous, 257 integer (15 binary)
#
# Root relaxation: objective 4.011279e+02, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  401.12794    0    7  568.84619  401.12794  29.5%     -    0s
# H    0     0                     543.3892813  401.12794  26.2%     -    0s
#      0     0  428.57777    0   10  543.38928  428.57777  21.1%     -    0s
# H    0     0                     473.8602933  428.57777  9.56%     -    0s
#      0     0  446.05823    0   12  473.86029  446.05823  5.87%     -    0s
#      0     0     cutoff    0       473.86029  473.86029  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.04 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 473.86 543.389 568.846
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.738602932973e+02, best bound 4.738602932973e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850720912]@(11.721698040786183, 6.9457024383108426).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 307 columns and 778 nonzeros
# Model fingerprint: 0x75129ca1
# Variable types: 0 continuous, 307 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 701.173
#
# Presolve removed 4 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 299 columns, 730 nonzeros
# Variable types: 0 continuous, 299 integer (29 binary)
#
# Root relaxation: objective 4.929414e+02, 66 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  492.94142    0   41  701.17290  492.94142  29.7%     -    0s
#      0     0  529.68841    0   58  701.17290  529.68841  24.5%     -    0s
# H    0     0                     633.3769879  529.68841  16.4%     -    0s
#      0     0  530.90336    0   50  633.37699  530.90336  16.2%     -    0s
#      0     0  537.06621    0   58  633.37699  537.06621  15.2%     -    0s
#      0     0  539.35931    0   65  633.37699  539.35931  14.8%     -    0s
#      0     0  540.08114    0   58  633.37699  540.08114  14.7%     -    0s
#      0     0  540.36732    0   66  633.37699  540.36732  14.7%     -    0s
# H    0     0                     627.6005234  540.36732  13.9%     -    0s
# H    0     0                     591.4031628  540.36732  8.63%     -    0s
#      0     0  542.73308    0   63  591.40316  542.73308  8.23%     -    0s
#      0     0  542.73308    0   40  591.40316  542.73308  8.23%     -    0s
#      0     0  542.73308    0   41  591.40316  542.73308  8.23%     -    0s
# H    0     0                     553.9302505  542.73308  2.02%     -    0s
#      0     0  542.73308    0   54  553.93025  542.73308  2.02%     -    0s
#      0     0  542.73308    0   63  553.93025  542.73308  2.02%     -    0s
#      0     0  542.73308    0   61  553.93025  542.73308  2.02%     -    0s
#      0     0  544.60769    0   66  553.93025  544.60769  1.68%     -    0s
#      0     0  544.60769    0   41  553.93025  544.60769  1.68%     -    0s
# H    0     0                     549.7535942  544.60769  0.94%     -    0s
#      0     0  549.75359    0   50  549.75359  549.75359  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   Zero half: 18
#   RLT: 1
#
# Explored 1 nodes (436 simplex iterations) in 0.12 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 549.754 553.93 591.403 ... 701.173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.497535942165e+02, best bound 5.497535942165e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 73 rows, 307 columns and 930 nonzeros
# Model fingerprint: 0x3de806e1
# Variable types: 0 continuous, 307 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 701.173
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R71 by 1.000000000
#
# Presolve removed 4 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 69 rows, 299 columns, 880 nonzeros
# Variable types: 0 continuous, 299 integer (29 binary)
#
# Root relaxation: objective 4.929414e+02, 67 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  492.94142    0   41  701.17290  492.94142  29.7%     -    0s
#      0     0  529.68841    0   58  701.17290  529.68841  24.5%     -    0s
# H    0     0                     633.3769879  529.68841  16.4%     -    0s
#      0     0  530.90336    0   50  633.37699  530.90336  16.2%     -    0s
#      0     0  536.67082    0   63  633.37699  536.67082  15.3%     -    0s
#      0     0  538.66078    0   66  633.37699  538.66078  15.0%     -    0s
#      0     0  540.02750    0   56  633.37699  540.02750  14.7%     -    0s
#      0     0  540.19733    0   66  633.37699  540.19733  14.7%     -    0s
#      0     0  540.23045    0   54  633.37699  540.23045  14.7%     -    0s
# H    0     0                     627.6005234  540.23045  13.9%     -    0s
# H    0     0                     591.4031628  540.23045  8.65%     -    0s
#      0     0  542.44315    0   58  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   41  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   44  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   63  591.40316  542.44315  8.28%     -    0s
#      0     0  542.44315    0   57  591.40316  542.44315  8.28%     -    0s
# H    0     0                     555.1612419  542.44315  2.29%     -    0s
#      0     0  542.44315    0   52  555.16124  542.44315  2.29%     -    0s
#      0     0  542.44315    0   59  555.16124  542.44315  2.29%     -    0s
#      0     0  543.18244    0   67  555.16124  543.18244  2.16%     -    0s
#      0     0  543.18244    0   21  555.16124  543.18244  2.16%     -    0s
# *    0     0               0     553.9302505  553.93025  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 5
#
# Explored 1 nodes (467 simplex iterations) in 0.13 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 553.93 555.161 591.403 ... 701.173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.539302505080e+02, best bound 5.539302505080e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850710864]@(10.402417084692415, 4.891181011186349).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 83 rows, 340 columns and 874 nonzeros
# Model fingerprint: 0x4bd20e45
# Variable types: 0 continuous, 340 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 486.448
#
# Presolve removed 15 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 320 columns, 734 nonzeros
# Variable types: 0 continuous, 320 integer (45 binary)
#
# Root relaxation: objective 4.322638e+02, 68 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  432.26375    0   45  486.44767  432.26375  11.1%     -    0s
# H    0     0                     482.2710154  442.75569  8.19%     -    0s
#      0     0  458.74964    0   61  482.27102  458.74964  4.88%     -    0s
#      0     0  458.74964    0   37  482.27102  458.74964  4.88%     -    0s
#      0     0  482.27102    0   49  482.27102  482.27102  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 8
#
# Explored 1 nodes (175 simplex iterations) in 0.05 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 482.271 486.448
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.822710154259e+02, best bound 4.822710154259e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 85 rows, 340 columns and 1032 nonzeros
# Model fingerprint: 0x9af8f896
# Variable types: 0 continuous, 340 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 486.448
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R83 by 1.000000000
#
# Presolve removed 15 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 70 rows, 320 columns, 890 nonzeros
# Variable types: 0 continuous, 320 integer (45 binary)
#
# Root relaxation: objective 4.322638e+02, 68 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  432.26375    0   45  486.44767  432.26375  11.1%     -    0s
#      0     0  457.93151    0   61  486.44767  457.93151  5.86%     -    0s
#      0     0  457.93151    0   38  486.44767  457.93151  5.86%     -    0s
#      0     0  458.19525    0   51  486.44767  458.19525  5.81%     -    0s
#      0     0  467.20444    0   50  486.44767  467.20444  3.96%     -    0s
# H    0     0                     484.2043074  467.20444  3.51%     -    0s
#      0     0  469.43894    0   50  484.20431  469.43894  3.05%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 3
#   GUB cover: 1
#   Zero half: 11
#
# Explored 1 nodes (201 simplex iterations) in 0.06 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 484.204 486.448
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.842043073588e+02, best bound 4.842043073588e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850749840]@(18.922018638506028, 13.766873054511441).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 302 columns and 769 nonzeros
# Model fingerprint: 0xe7356a3d
# Variable types: 0 continuous, 302 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 622.187
#
# Presolve removed 8 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 298 columns, 740 nonzeros
# Variable types: 0 continuous, 298 integer (27 binary)
#
# Root relaxation: objective 5.766232e+02, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  576.62317    0   35  622.18733  576.62317  7.32%     -    0s
#      0     0  599.73956    0   30  622.18733  599.73956  3.61%     -    0s
#      0     0  599.73956    0   29  622.18733  599.73956  3.61%     -    0s
#      0     0     cutoff    0       622.18733  622.18733  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Cover: 2
#   MIR: 2
#   Zero half: 9
#
# Explored 1 nodes (179 simplex iterations) in 0.05 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 622.187
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.221873250970e+02, best bound 6.221873250970e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850734928]@(15.077489302267177, 13.296239996551405).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 69 rows, 302 columns and 709 nonzeros
# Model fingerprint: 0xfb229cf3
# Variable types: 0 continuous, 302 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 454.735
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 293 columns, 653 nonzeros
# Variable types: 0 continuous, 293 integer (24 binary)
#
# Root relaxation: objective 3.837629e+02, 47 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     383.7629015  383.76290  0.00%     -    0s
#
# Explored 0 nodes (47 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 383.763 454.735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.837629015052e+02, best bound 3.837629015052e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 71 rows, 302 columns and 833 nonzeros
# Model fingerprint: 0xe16f10d6
# Variable types: 0 continuous, 302 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 454.735
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R69 by 2.000000000
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 63 rows, 293 columns, 774 nonzeros
# Variable types: 0 continuous, 293 integer (24 binary)
#
# Root relaxation: objective 3.879672e+02, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  387.96719    0   19  454.73487  387.96719  14.7%     -    0s
# H    0     0                     444.0882829  387.96719  12.6%     -    0s
# H    0     0                     410.2704797  387.96719  5.44%     -    0s
# H    0     0                     393.0265096  387.96719  1.29%     -    0s
# H    0     0                     390.5233470  387.96719  0.65%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   Zero half: 1
#
# Explored 1 nodes (58 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 390.523 393.027 410.27 ... 454.735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.905233469657e+02, best bound 3.905233469657e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850720656]@(9.380039438154913, 7.080127466299323).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 75 rows, 308 columns and 737 nonzeros
# Model fingerprint: 0x39fe7a67
# Variable types: 0 continuous, 308 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 465.004
#
# Presolve removed 15 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 295 columns, 646 nonzeros
# Variable types: 0 continuous, 295 integer (29 binary)
#
# Root relaxation: objective 4.193286e+02, 58 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  419.32863    0   30  465.00438  419.32863  9.82%     -    0s
# H    0     0                     453.2982146  420.79734  7.17%     -    0s
#      0     0  433.98211    0   31  453.29821  433.98211  4.26%     -    0s
# *    0     0               0     449.0383305  449.03833  0.00%     -    0s
#
# Explored 1 nodes (103 simplex iterations) in 0.04 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 449.038 453.298 465.004
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.490383304907e+02, best bound 4.490383304907e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850709712]@(6.859258434638642, 4.330752520800434).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 302 columns and 763 nonzeros
# Model fingerprint: 0x1828d63d
# Variable types: 0 continuous, 302 integer (19 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 362.82
#
# Presolve removed 11 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 294 columns, 705 nonzeros
# Variable types: 0 continuous, 294 integer (29 binary)
#
# Root relaxation: objective 3.626506e+02, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       362.82032  362.82032  0.00%     -    0s
#
# Explored 0 nodes (56 simplex iterations) in 0.01 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 362.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.628203196584e+02, best bound 3.628203196584e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850734544]@(11.780238183522124, 13.26259715481488).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 58 rows, 278 columns and 485 nonzeros
# Model fingerprint: 0x3d269cea
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
#
# Presolve removed 9 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 273 columns, 463 nonzeros
# Variable types: 0 continuous, 273 integer (7 binary)
#
# Root relaxation: objective 2.689890e+02, 21 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     268.9889529  268.98895  0.00%     -    0s
#
# Explored 0 nodes (21 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 268.989 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.689889529064e+02, best bound 2.689889529064e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 60 rows, 278 columns and 534 nonzeros
# Model fingerprint: 0x2da95d52
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R58 by 1.000000000
#
# Presolve removed 10 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 272 columns, 507 nonzeros
# Variable types: 0 continuous, 272 integer (6 binary)
#
# Root relaxation: objective 3.017281e+02, 25 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  301.72807    0   10  347.89941  301.72807  13.3%     -    0s
# H    0     0                     346.0396985  301.72807  12.8%     -    0s
# H    0     0                     336.3634743  301.72807  10.3%     -    0s
# H    0     0                     304.4639641  301.72807  0.90%     -    0s
#
# Explored 1 nodes (25 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 304.464 336.363 346.04 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.044639641132e+02, best bound 3.044639641132e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 3 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 63 rows, 278 columns and 562 nonzeros
# Model fingerprint: 0x9d4e87fd
# Variable types: 0 continuous, 278 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 347.899
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R60 by 2.000000000
#
# Presolve removed 11 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 271 columns, 527 nonzeros
# Variable types: 0 continuous, 271 integer (5 binary)
#
# Root relaxation: objective 3.088107e+02, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  310.51342    0   13  347.89941  310.51342  10.7%     -    0s
# H    0     0                     316.2740426  310.51342  1.82%     -    0s
#      0     0  310.51342    0   13  316.27404  310.51342  1.82%     -    0s
#
# Explored 1 nodes (29 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 316.274 347.899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.162740425746e+02, best bound 3.162740425746e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850711376]@(7.561772039668687, 6.3301042491376665).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 80 rows, 307 columns and 730 nonzeros
# Model fingerprint: 0xde9f9037
# Variable types: 0 continuous, 307 integer (15 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 435.442
#
# Presolve removed 19 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 295 columns, 661 nonzeros
# Variable types: 0 continuous, 295 integer (28 binary)
#
# Root relaxation: objective 4.352728e+02, 70 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       435.44248  435.44248  0.00%     -    0s
#
# Explored 0 nodes (70 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 435.442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.354424818767e+02, best bound 4.354424818767e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850722832]@(3.450661739619864, 9.808861413176789).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 62 rows, 252 columns and 608 nonzeros
# Model fingerprint: 0xbed957e3
# Variable types: 0 continuous, 252 integer (11 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 529.773
#
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 252 columns, 608 nonzeros
# Variable types: 0 continuous, 252 integer (12 binary)
#
# Root relaxation: objective 4.570408e+02, 44 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  457.04081    0    7  529.77317  457.04081  13.7%     -    0s
#      0     0  477.03739    0    8  529.77317  477.03739  10.0%     -    0s
#      0     0  477.03739    0    6  529.77317  477.03739  10.0%     -    0s
#      0     0     cutoff    0       529.77317  529.77317  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 1
#   Zero half: 2
#
# Explored 1 nodes (91 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 529.773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.297731695401e+02, best bound 5.297731695401e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329851120528]@(3.5491912569691024, 13.314972840739191).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 57 rows, 279 columns and 568 nonzeros
# Model fingerprint: 0xa1962c08
# Variable types: 0 continuous, 279 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 319.118
#
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 277 columns, 546 nonzeros
# Variable types: 0 continuous, 277 integer (13 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       319.11779  319.11779  0.00%     -    0s
#
# Explored 0 nodes (33 simplex iterations) in 0.01 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 319.118
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.191177885133e+02, best bound 3.191177885133e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850752016]@(18.555063203446714, 15.667119337248085).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 296 columns and 751 nonzeros
# Model fingerprint: 0xba467f61
# Variable types: 0 continuous, 296 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 494.919
#
# Presolve removed 12 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 64 rows, 287 columns, 695 nonzeros
# Variable types: 0 continuous, 287 integer (28 binary)
#
# Root relaxation: objective 4.507433e+02, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  450.74335    0   27  494.91946  450.74335  8.93%     -    0s
#      0     0  482.73380    0   28  494.91946  482.73380  2.46%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (78 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 494.919
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.949194600656e+02, best bound 4.949194600656e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850766672]@(0.7883485356521597, 10.629352453039107).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 66 rows, 252 columns and 608 nonzeros
# Model fingerprint: 0xe47b5f25
# Variable types: 0 continuous, 252 integer (11 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 529.773
#
# Presolve removed 6 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 252 columns, 608 nonzeros
# Variable types: 0 continuous, 252 integer (12 binary)
#
# Root relaxation: objective 4.570408e+02, 46 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  457.04081    0    7  529.77317  457.04081  13.7%     -    0s
#      0     0  477.03739    0   10  529.77317  477.03739  10.0%     -    0s
#      0     0     cutoff    0       529.77317  529.77317  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 529.773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.297731695401e+02, best bound 5.297731695401e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850749200]@(13.83963526377084, 14.691667640449392).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 73 rows, 304 columns and 662 nonzeros
# Model fingerprint: 0xb08464d3
# Variable types: 0 continuous, 304 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 308.304
#
# Presolve removed 16 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 293 columns, 600 nonzeros
# Variable types: 0 continuous, 293 integer (25 binary)
#
# Root relaxation: objective 2.938443e+02, 42 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     293.8443348  293.84433  0.00%     -    0s
#
# Explored 0 nodes (42 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 293.844 308.304
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.938443347599e+02, best bound 2.938443347599e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 75 rows, 304 columns and 772 nonzeros
# Model fingerprint: 0x3ee117da
# Variable types: 0 continuous, 304 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 308.304
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R73 by 1.000000000
#
# Presolve removed 16 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 293 columns, 704 nonzeros
# Variable types: 0 continuous, 293 integer (25 binary)
#
# Root relaxation: objective 3.010741e+02, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  304.07238    0   10  308.30395  304.07238  1.37%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (53 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 308.304
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.083039462268e+02, best bound 3.083039462268e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850708560]@(11.015224261353866, 2.8014162578668507).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 82 rows, 316 columns and 804 nonzeros
# Model fingerprint: 0xb8777a03
# Variable types: 0 continuous, 316 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [8e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 373.575
#
# Presolve removed 17 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 303 columns, 713 nonzeros
# Variable types: 0 continuous, 303 integer (34 binary)
#
# Root relaxation: cutoff, 38 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       373.57468  373.57468  0.00%     -    0s
#
# Explored 0 nodes (38 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 373.575
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.735746783362e+02, best bound 3.735746783362e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850722448]@(10.742012801935333, 8.998425668654535).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 72 rows, 291 columns and 610 nonzeros
# Model fingerprint: 0xd1b6904f
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
#
# Presolve removed 15 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 281 columns, 560 nonzeros
# Variable types: 0 continuous, 281 integer (23 binary)
#
# Root relaxation: objective 3.599007e+02, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     359.9006725  359.90067  0.00%     -    0s
#
# Explored 0 nodes (48 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 359.901 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.599006725172e+02, best bound 3.599006725172e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 74 rows, 291 columns and 686 nonzeros
# Model fingerprint: 0x861de559
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R72 by 1.000000000
#
# Presolve removed 18 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 277 columns, 621 nonzeros
# Variable types: 0 continuous, 277 integer (18 binary)
#
# Root relaxation: objective 3.953456e+02, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  395.34561    0   25  431.93750  395.34561  8.47%     -    0s
# H    0     0                     413.1938524  395.34561  4.32%     -    0s
#      0     0     cutoff    0       413.19385  413.19385  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (53 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 413.194 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.131938524474e+02, best bound 4.131938524474e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 291 columns and 779 nonzeros
# Model fingerprint: 0xb5a36801
# Variable types: 0 continuous, 291 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 431.938
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R74 by 1.000000000
#
# Presolve removed 18 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 277 columns, 710 nonzeros
# Variable types: 0 continuous, 277 integer (18 binary)
#
# Root relaxation: objective 3.953456e+02, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  395.34561    0   25  431.93750  395.34561  8.47%     -    0s
# *    0     0               0     414.5672949  414.56729  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 1
#   Zero half: 5
#
# Explored 1 nodes (63 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 414.567 431.938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.145672949195e+02, best bound 4.145672949195e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850723600]@(10.899309734342483, 11.144536799566804).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 68 rows, 289 columns and 495 nonzeros
# Model fingerprint: 0xdd44c0ed
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 282 columns, 471 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.433159e+02, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     243.3159220  243.31592  0.00%     -    0s
#
# Explored 0 nodes (18 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 243.316 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.433159219869e+02, best bound 2.433159219869e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 70 rows, 289 columns and 556 nonzeros
# Model fingerprint: 0x58482bce
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R68 by 1.000000000
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 282 columns, 531 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.565171e+02, 26 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  256.51706    0    6  337.09271  256.51706  23.9%     -    0s
# H    0     0                     278.9055543  256.51706  8.03%     -    0s
#      0     0  266.33935    0    7  278.90555  266.33935  4.51%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 1
#
# Explored 1 nodes (30 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 278.906 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.789055543438e+02, best bound 2.789055543438e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 72 rows, 289 columns and 618 nonzeros
# Model fingerprint: 0x7c208b1d
# Variable types: 0 continuous, 289 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 337.093
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R70 by 2.000000000
#
# Presolve removed 18 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 282 columns, 593 nonzeros
# Variable types: 0 continuous, 282 integer (11 binary)
#
# Root relaxation: objective 2.565171e+02, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  256.51706    0    6  337.09271  256.51706  23.9%     -    0s
# H    0     0                     292.6971391  256.51706  12.4%     -    0s
#      0     0  270.93654    0   19  292.69714  270.93654  7.43%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 1
#
# Explored 1 nodes (34 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 292.697 337.093
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.926971390551e+02, best bound 2.926971390551e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850724112]@(9.516861784299248, 12.361285732935182).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 59 rows, 257 columns and 425 nonzeros
# Model fingerprint: 0xbdab340a
# Variable types: 0 continuous, 257 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 222.64
#
# Presolve removed 13 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 254 columns, 422 nonzeros
# Variable types: 0 continuous, 254 integer (7 binary)
#
# Root relaxation: objective 1.811143e+02, 16 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     181.1143392  181.11434  0.00%     -    0s
#
# Explored 0 nodes (16 simplex iterations) in 0.01 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 181.114 222.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.811143391763e+02, best bound 1.811143391763e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 2 cycles.
# Adding subtour elimination constraint.
# Adding subtour elimination constraint.
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 61 rows, 257 columns and 451 nonzeros
# Model fingerprint: 0x3116f0ab
# Variable types: 0 continuous, 257 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# Loaded user MIP start with objective 222.64
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R59 by 1.000000000
#
# Presolve removed 15 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 252 columns, 440 nonzeros
# Variable types: 0 continuous, 252 integer (6 binary)
#
# Root relaxation: objective 2.134332e+02, 23 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       222.63981  222.63981  0.00%     -    0s
#
# Explored 0 nodes (23 simplex iterations) in 0.02 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 222.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.226398118404e+02, best bound 2.226398118404e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.
# Optimize tour around PointVertex[140329850710352]@(5.55, 5.765491662848854).
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 76 rows, 289 columns and 682 nonzeros
# Model fingerprint: 0xd766ac3a
# Variable types: 0 continuous, 289 integer (14 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 357.358
#
# Presolve removed 17 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 59 rows, 281 columns, 624 nonzeros
# Variable types: 0 continuous, 281 integer (24 binary)
#
# Root relaxation: objective 3.571882e+02, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       357.35797  357.35797  0.00%     -    0s
#
# Explored 0 nodes (55 simplex iterations) in 0.03 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 357.358
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.573579675195e+02, best bound 3.573579675195e+02, gap 0.0000%
# Checking for cycles in solution.
# Found 1 cycles.

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 7))
gs = fig.add_gridspec(5, 4, hspace=0, wspace=0)
axes = gs.subplots(sharex="col", sharey="row")

for i, (A, sol) in enumerate(solutions):
    t = create_cycle_solution(gi.graph, sol)[0]
    if i == 20:
        break
    ax = axes[i // 4, i % 4]
    ax.set_aspect("equal", adjustable="box")
    plot_polygon_instance(ax, pi, plot_valuable_areas=True)
    plot_graph(ax, gi.graph, marker=".", vertex_color="grey", edge_color="grey", size=3)
    plot_solution(ax, t.waypoints(), color="blue", w=1.5)
    if i > 0:
        diff = sol - solutions[i - 1][1]
        plot_fractional_solution(ax, diff, color="darkred", zorder=3, linewidth=2)
        ax.scatter([p.x for p in A], [p.y for p in A], color="red", zorder=2, alpha=0.5)
plt.tight_layout()
plt.savefig("11_grid.pdf")
plt.show()
