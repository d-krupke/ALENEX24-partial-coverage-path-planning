# %% [markdown]
# # Comparing the best and the worst alignement for grids
#
# How sensitive are the grids to missalignment.
# We compare the best alignment of a grid to its worst.

# %%
from bisect import bisect

from aemeasure import read_as_pd
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
from _utils import convert_to_percentage_interval

from pcpptc import PolygonInstance, Solution
from pcpptc.plot import setup_plot, plot_polygon_instance, plot_solution
from pcpptc.plot.polgyon_instance import plot_coverage

# %%
read_as_pd("./solutions/1.results.json").columns
# Out:
# Loaded dataframe ./solutions/1.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 14:37:25.626364 and 2021-06-01 01:37:18.179121
# Index(['instance', 'instance_path', 'runtime', 'timestamp', 'hostname', 'argv',
#        'git_revision', 'solver', 'solution', 'i', 'coverage', 'touring_cost',
#        'length', 'turn_sum', 'turn_factor'],
#       dtype='object')

# %%
tables = []
for f in os.listdir("./solutions"):
    if not f.endswith(".results.json"):
        continue
    f = os.path.join("./solutions", f)
    tables.append(read_as_pd(f))

data = pd.concat(tables, ignore_index=True)
# data.dropna(inplace=True)
# Out:
# Loaded dataframe ./solutions/75.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:56:32.369542 and 2021-05-30 23:12:51.253141
# Loaded dataframe ./solutions/156.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 15:40:10.168809 and 2021-06-02 05:39:33.243133
# Loaded dataframe ./solutions/119.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:59:00.092247 and 2021-05-31 04:52:30.695564
# Loaded dataframe ./solutions/173.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:46:18.925022 and 2021-06-01 05:44:43.928209
# Loaded dataframe ./solutions/144.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:03:49.638596 and 2021-05-30 23:25:05.968252
# Loaded dataframe ./solutions/185.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 19:44:53.863266 and 2021-06-02 03:48:34.655858
# Loaded dataframe ./solutions/154.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:35:54.058267 and 2021-05-31 11:26:07.922981
# Loaded dataframe ./solutions/12.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:06:17.976001 and 2021-06-01 14:17:40.968197
# Loaded dataframe ./solutions/197.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:22:36.958358 and 2021-05-31 10:36:48.403232
# Loaded dataframe ./solutions/86.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 22:51:38.692059 and 2021-05-29 18:17:30.910563
# Loaded dataframe ./solutions/35.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 18:15:05.480879 and 2021-06-02 06:51:39.239273
# Loaded dataframe ./solutions/74.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 14:51:19.517077 and 2021-06-01 01:54:50.299628
# Loaded dataframe ./solutions/57.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:46:35.023238 and 2021-05-31 10:58:58.890563
# Loaded dataframe ./solutions/58.results.json
# Executed on: ['algry02']
# During: 2021-05-28 17:41:41.539291 and 2021-05-30 13:27:55.120445
# Loaded dataframe ./solutions/14.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:46:24.513551 and 2021-05-30 23:07:20.282313
# Loaded dataframe ./solutions/3.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 15:47:49.114041 and 2021-06-01 17:00:44.628054
# Loaded dataframe ./solutions/36.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:05:59.067423 and 2021-05-31 10:15:11.696160
# Loaded dataframe ./solutions/80.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:50:09.457868 and 2021-05-31 11:41:23.635541
# Loaded dataframe ./solutions/70.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:08:50.282853 and 2021-05-30 15:18:17.455690
# Loaded dataframe ./solutions/45.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 19:39:34.700957 and 2021-06-02 03:39:56.248293
# Loaded dataframe ./solutions/21.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:21:50.840581 and 2021-06-02 07:37:30.564733
# Loaded dataframe ./solutions/17.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21
results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:02:34.109415 and 2021-05-31 14:09:49.925876
# Loaded dataframe ./solutions/65.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:04:18.568701 and 2021-06-01 06:30:30.555635
# Loaded dataframe ./solutions/133.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 22:00:54.469959 and 2021-05-29 17:48:01.921427
# Loaded dataframe ./solutions/77.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 12:31:58.972622 and 2021-05-30 06:18:33.848059
# Loaded dataframe ./solutions/183.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:52:22.195613 and 2021-05-31 09:33:55.509282
# Loaded dataframe ./solutions/98.results.json
# Executed on: ['algry02']
# During: 2021-05-28 13:29:28.236111 and 2021-05-30 10:13:25.290402
# Loaded dataframe ./solutions/128.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 10:39:38.501402 and 2021-05-30 04:36:54.591786
# Loaded dataframe ./solutions/107.results.json
# Executed on: ['algry02']
# During: 2021-05-28 18:43:21.570207 and 2021-05-30 13:56:10.073274
# Loaded dataframe ./solutions/24.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:18:07.058790 and 2021-06-01 21:39:08.648387
# Loaded dataframe ./solutions/166.results.json
# Executed on: ['algry02']
# During: 2021-05-28 15:27:08.691970 and 2021-05-30 11:56:48.762184
# Loaded dataframe ./solutions/85.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:31:56.371921 and 2021-05-31 14:44:00.868481
# Loaded dataframe ./solutions/81.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:30:09.492572 and 2021-05-31 08:58:11.700991
# Loaded dataframe ./solutions/90.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:08:31.647594 and 2021-05-31 01:54:54.793743
# Loaded dataframe ./solutions/139.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 14:19:30.688333 and 2021-05-30 08:17:09.998517
# Loaded dataframe ./solutions/78.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 23:16:16.141124 and 2021-05-29 18:37:23.622452
# Loaded dataframe ./solutions/165.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 18:20:29.386180 and 2021-06-01 11:30:27.894314
# Loaded dataframe ./solutions/164.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 13:54:01.278001 and 2021-05-30 07:34:39.408195
# Loaded dataframe ./solutions/87.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:08:44.606877 and 2021-06-01 19:50:41.745523
# Loaded dataframe ./solutions/116.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:39:47.482017 and 2021-05-30 19:20:04.484902
# Loaded dataframe ./solutions/141.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:55:06.356491 and 2021-05-31 07:35:44.198117
# Loaded dataframe ./solutions/182.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:05:16.791909 and 2021-05-31 13:42:17.158473
# Loaded dataframe ./solutions/60.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:16:24.984107 and 2021-06-01 01:34:52.849849
# Loaded dataframe ./solutions/184.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 07:20:28.202489 and 2021-05-30 03:06:36.600698
# Loaded dataframe ./solutions/171.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 19:56:41.261588 and 2021-06-01 12:22:43.087720
# Loaded dataframe ./solutions/100.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 09:08:22.127863 and 2021-05-30 03:14:26.900263
# Loaded dataframe ./solutions/2.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 10:14:52.862518 and 2021-05-30 04:28:14.409791
# Loaded dataframe ./solutions/178.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 14:32:41.380717 and 2021-05-31 06:05:50.623910
# Loaded dataframe ./solutions/69.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 17:43:41.233511 and 2021-05-29 14:20:53.731814
# Loaded dataframe ./solutions/176.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:11:41.715742 and 2021-05-31 22:20:47.240877
# Loaded dataframe ./solutions/102.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:00:35.855804 and 2021-05-30 19:01:34.063442
# Loaded dataframe ./solutions/67.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:52:58.454589 and 2021-06-01 16:00:31.440436
# Loaded dataframe ./solutions/148.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:14:02.645394 and 2021-06-01 19:03:15.869298
# Loaded dataframe ./solutions/140.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:02:00.828034 and 2021-05-31 11:45:36.126197
# Loaded dataframe ./solutions/151.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:47:51.401374 and 2021-05-31 17:18:47.658950
# Loaded dataframe ./solutions/4.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:13:52.918027 and 2021-06-01 06:48:29.558056
# Loaded dataframe ./solutions/123.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 20:15:06.563912 and 2021-06-02 04:32:55.947392
# Loaded dataframe ./solutions/157.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 17:23:22.503568 and 2021-05-29 14:04:46.048330
# Loaded dataframe ./solutions/55.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 21:53:51.327337 and 2021-05-29 17:10:12.315642
# Loaded dataframe ./solutions/192.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:52:53.015873 and 2021-05-31 02:40:46.933775
# Loaded dataframe ./solutions/195.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 21:14:26.911807 and 2021-05-29 17:04:29.707224
# Loaded dataframe ./solutions/26.results.json
# Executed on: ['algry02']
# During: 2021-05-28 23:13:18.163232 and 2021-05-31 21:44:15.914624
# Loaded dataframe ./solutions/124.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:13:08.635867 and 2021-05-31 20:14:20.437843
# Loaded dataframe ./solutions/198.results.json
# Executed on: ['algry02']
# During: 2021-05-28 16:38:39.016299 and 2021-05-30 12:51:08.303218
# Loaded dataframe ./solutions/147.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:49:57.989952 and 2021-06-01 20:07:00.450571
# Loaded dataframe ./solutions/111.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 12:43:41.668552 and 2021-05-30 07:25:21.745920
# Loaded dataframe ./solutions/162.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:45:38.160434 and 2021-05-31 23:47:42.392681
# Loaded dataframe ./solutions/63.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 11:07:31.328334 and 2021-05-30 05:29:11.837230
# Loaded dataframe ./solutions/82.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:26:25.071335 and 2021-06-02 06:17:04.439951
# Loaded dataframe ./solutions/150.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:02:30.860090 and 2021-05-31 00:06:24.737175
# Loaded dataframe ./solutions/187.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:43:03.001940 and 2021-05-31 21:57:35.158952
# Loaded dataframe ./solutions/72.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 14:51:56.496909 and 2021-05-30 08:28:51.581681
# Loaded dataframe ./solutions/31.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 05:36:10.397925 and 2021-05-30 01:41:24.735731
# Loaded dataframe ./solutions/25.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 05:01:03.118215 and 2021-05-29 23:37:07.478294
# Loaded dataframe ./solutions/34.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 19:15:56.759216 and 2021-05-29 14:49:05.169304
# Loaded dataframe ./solutions/108.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:01:43.417862 and 2021-05-31 10:04:51.442858
# Loaded dataframe ./solutions/105.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 14:04:44.372128 and 2021-05-30 07:39:38.498560
# Loaded dataframe ./solutions/42.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 09:54:19.759852 and 2021-05-31 12:00:27.371180
# Loaded dataframe ./solutions/155.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:37:59.569441 and 2021-05-31 06:57:04.261828
# Loaded dataframe ./solutions/138.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:59:31.629513 and 2021-06-01 13:12:05.508892
# Loaded dataframe ./solutions/51.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:39:53.742385 and 2021-06-01 23:44:53.957436
# Loaded dataframe ./solutions/95.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:44:39.713586 and 2021-05-31 07:03:29.834559
# Loaded dataframe ./solutions/8.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 16:50:59.134774 and 2021-05-29 13:54:57.174388
# Loaded dataframe ./solutions/103.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:40:37.780117 and 2021-05-31 23:36:39.106038
# Loaded dataframe ./solutions/43.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:27:48.358465 and 2021-05-31 10:01:17.437229
# Loaded dataframe ./solutions/177.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 14:34:07.402649 and 2021-05-30 18:09:27.764972
# Loaded dataframe ./solutions/33.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:24:39.038722 and 2021-05-31 06:51:34.110914
# Loaded dataframe ./solutions/15.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 14:40:19.021225 and 2021-06-01 01:46:59.300089
# Loaded dataframe ./solutions/23.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:28:06.578144 and 2021-05-31 14:39:25.034538
# Loaded dataframe ./solutions/109.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 11:55:45.041140 and 2021-05-31 13:48:08.824244
# Loaded dataframe ./solutions/89.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 12:02:50.983623 and 2021-05-30 06:08:42.607730
# Loaded dataframe ./solutions/56.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:34:22.761018 and 2021-05-31 14:17:42.262156
# Loaded dataframe ./solutions/30.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 16:53:26.492791 and 2021-06-02 03:35:23.165488
# Loaded dataframe ./solutions/117.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 12:37:00.958626 and 2021-05-31 23:56:03.906762
# Loaded dataframe ./solutions/175.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 09:13:50.010830 and 2021-05-30 03:32:14.990254
# Loaded dataframe ./solutions/120.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 10:52:19.003574 and 2021-05-31 07:05:26.270082
# Loaded dataframe ./solutions/20.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-26 20:17:37.774161 and 2021-05-29 16:28:08.309237
# Loaded dataframe ./solutions/113.results.json
# Executed on: ['algry02']
# During: 2021-05-28 18:22:49.500589 and 2021-05-30 13:41:01.666115
# Loaded dataframe ./solutions/19.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 01:01:04.913401 and 2021-05-29 19:59:22.207687
# Loaded dataframe ./solutions/106.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:08:01.518018 and 2021-06-01 06:02:45.782953
# Loaded dataframe ./solutions/172.results.json
# Executed on: ['algry02']
# During: 2021-05-28 18:37:04.073668 and 2021-05-30 13:46:28.398568
# Loaded dataframe ./solutions/18.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 15:07:46.160767 and 2021-06-01 20:54:03.575202
# Loaded dataframe ./solutions/27.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 13:18:33.751521 and 2021-05-31 05:57:57.946164
# Loaded dataframe ./solutions/152.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 01:05:49.583897 and 2021-05-29 20:15:41.874970
# Loaded dataframe ./solutions/159.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-21 17:46:24.278878 and 2021-06-01 15:56:36.688071
# Loaded dataframe ./solutions/190.results.json
# Executed on: ['algry01' 'algry02']
# During: 2021-05-27 05:04:06.041238 and 2021-05-29 23:39:44.058165

# %%
def descr(solver):
    if "hex" in solver.lower():
        type = "Hexagonal"
    elif "square" in solver.lower():
        type = "Square"
    else:
        raise ValueError(f"Could not detect type of {solver}")
    if "pb=True" in solver or "point_based=True" in solver:
        d = "Point-based"
    elif "pb=False" in solver or "point_based=False" in solver:
        d = "Line-based"
    else:
        raise ValueError(f"Could not detect base of {solver}")
    return f"{type}, {d}"


data["Grid"] = data["solver"].apply(descr)

data.groupby("Grid")["instance"].nunique()
# Out:
# Grid
# Hexagonal, Line-based     200
# Hexagonal, Point-based    139
# Square, Line-based        200
# Square, Point-based       139
# Name: instance, dtype: int64

# %%
data.dropna(inplace=True)

# %%
# add instance area
instance_paths = list(data["instance_path"].unique())
instances = [PolygonInstance.from_json(file_path=f) for f in instance_paths]
instance_areas = pd.DataFrame(
    data={"area": [i.original_area.area for i in instances]}, index=instance_paths
)
data = data.merge(instance_areas, left_on="instance_path", right_index=True)
data["relative_coverage"] = 100 * data["coverage"] / data["area"]

# %%
best_aligned = data.groupby(["instance", "Grid"])[["touring_cost"]].min()
worst_aligned = data.groupby(["instance", "Grid"])[["touring_cost"]].max()
t = best_aligned.merge(
    right=worst_aligned, suffixes=("_min", "_max"), left_index=True, right_index=True
).reset_index()
t["diff"] = (100 * t["touring_cost_max"] / t["touring_cost_min"]) - 100
t
# Out:
#     instance                    Grid  touring_cost_min  touring_cost_max  \
# 0          0   Hexagonal, Line-based        458.543796        691.884979
# 1          0      Square, Line-based        489.389372        869.187125
# 2          1   Hexagonal, Line-based        605.740807       1008.015307
# 3          1  Hexagonal, Point-based        818.265721       1112.097697
# 4          1      Square, Line-based        563.911486       1478.412496
# ..       ...                     ...               ...               ...
# 673       98      Square, Line-based      14087.698328      22989.850828
# 674       99   Hexagonal, Line-based       3428.514300       4751.984464
# 675       99  Hexagonal, Point-based       4525.093461       4797.503462
# 676       99      Square, Line-based       3503.858377       6833.882812
# 677       99     Square, Point-based       4941.113126       6465.884058
#
#            diff
# 0     50.887436
# 1     77.606457
# 2     66.410335
# 3     35.909115
# 4    162.171020
# ..          ...
# 673   63.190965
# 674   38.601856
# 675    6.019986
# 676   95.038785
# 677   30.858855
#
# [678 rows x 5 columns]

# %%
# add instance information

instance_data = data.groupby(["instance"])[["area", "turn_factor"]].min()
t = t.merge(right=instance_data, left_on="instance", right_index=True)
t.sort_values(["Grid"], inplace=True)

# %%
data_area_interval = convert_to_percentage_interval(t, on_column="area", percentage=5)
data_area_interval.sort_values(by=["Grid"], ascending=False, inplace=True)


def rename(x):
    return x if "Square" in x else x.replace("Hexagonal", "Triangular")


data_area_interval["Grid"] = data_area_interval["Grid"].apply(rename)
t["Grid"] = t["Grid"].apply(rename)

# %%
plt.figure(figsize=(5, 3.5))
sns.lineplot(data=data_area_interval, x="area", y="diff", hue="Grid")
plt.legend(loc="upper right")
plt.ylabel("Difference of touring cost (%)")
plt.xlabel("Area ±5%")
plt.title("Lower is better")
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("././output/05_best_vs_worst_area.pdf")
plt.show()

# %%
plt.figure(figsize=(5, 3.5))
sns.boxplot(data=t, x="turn_factor", y="diff", hue="Grid")
plt.ylabel("Difference of touring cost (%)")
plt.xlabel("Optimization Weight of Turn-Cost")
plt.title("Lower is better")
plt.legend(loc="upper right")
# plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig("././output/05_best_vs_worst_turn_factor.pdf")
plt.show()

# %%
data.groupby(["Grid"])["instance"].nunique()
# Out:
# Grid
# Hexagonal, Line-based     200
# Hexagonal, Point-based    139
# Square, Line-based        200
# Square, Point-based       139
# Name: instance, dtype: int64
