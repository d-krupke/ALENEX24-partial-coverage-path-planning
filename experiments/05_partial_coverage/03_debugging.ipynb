# %%
import matplotlib.pyplot as plt
from pcpptc.plot import plot_polygon_instance, setup_plot
from pcpptc import PolygonInstance

instance = "./instances2/11.instance.json"
instance = PolygonInstance.from_json(file_path=instance)

ax = setup_plot()
plot_polygon_instance(ax, instance)
plt.show()

# %%
from pcpptc import MeshAlgorithm

alg = MeshAlgorithm()
tour = alg(instance)
# Out:
# Converting polygon instance to grid instance...
# Optimize grid with CVT-full
# Grid Solver:
# ==============================
# Cycle Cover Solver:
# Using linear programming and blossom matching to compute a cycle cover with turn-aware, heterogeneous touring costs.
# IntegralizingFractionalSolverComputing a fractional solution with some BnB steps to improve integrality.Up to 50 BnB steps are performed.
# NeighborBasedStripStrategy selecting 6 atomic strips first on usage than on minimizing the worst case overhead.
# ------------------------------
# Local Relaxation CC Optimization:
#  - AreaSelector with area size 50.
#          Selects the vertex that in sum with its direct neighbors has the highest
#          coverage costs plus opportunity loss.
#
# - Repeating 25 times.
# ------------------------------
# Local Relaxation Tour Optimization:
# - Like CC version but trying to reconnect unconnected solutions up to 10 times.
#  - AreaSelector with area size 50.
#          Selects the vertex that in sum with its direct neighbors has the highest
#          coverage costs plus opportunity loss.
#
# - Repeating 25 times.
# ==============================
#
# Instance
# ---------------------------------
# Vertices: 1020
# Edges: 2882
# Max Degree: 7
# Max value: 119.14004944864125
# Cycle Cover: Computing fractional solution...
# Academic license - for non-commercial use only - expires 2021-09-25
# Using license file /home/ANONYMOUS_USER/gurobi.lic
# Cycle Cover: Creating matching problem...
# Using adaptive strip selection strategy.
# Cycle Cover: Solving matching...
# Solve matching on 385979 edges.
# Optimize CC around PointVertex[140456911564176]@(3.964371685042456, -17.541767067338146).
# Optimize CC around PointVertex[140456911564432]@(8.574457429316318, -17.530648138484636).
# Optimize CC around PointVertex[140456911585232]@(0.670668561421341, -15.310942487813575).
# Optimize CC around PointVertex[140456911534864]@(6.153078314002237, -21.39129288634248).
# Optimize CC around PointVertex[140456911136272]@(-4.094104092631572, -33.50562599966977).
# Optimize CC around PointVertex[140456911164176]@(-6.7083397862502645, -41.37474826147807).
# Optimize CC around PointVertex[140456911144016]@(-6.514975400635969, -37.13408671325745).
# Optimize CC around PointVertex[140456911196048]@(-19.738944919903187, -46.1790835497642).
# Optimize CC around PointVertex[140456911534608]@(1.3294300365664204, -21.753269158422615).
# Optimize CC around PointVertex[140456911146704]@(-0.16989498799296485, -35.52516757637229).
# Optimize CC around PointVertex[140456911547728]@(12.002932905033772, -19.33874103284783).
# Optimize CC around PointVertex[140456911585936]@(12.100641074134264, -15.622953499949327).
# Optimize CC around PointVertex[140456911507344]@(4.167186626364177, -25.378205850550913).
# Optimize CC around PointVertex[140456911163920]@(-10.668334312720479, -42.36910408099239).
# Optimize CC around PointVertex[140456911602768]@(4.056256483100346, -13.519790215077776).
# Optimize CC around PointVertex[140456911193872]@(-23.34604272597013, -48.82153566933256).
# Optimize CC around PointVertex[140456911179728]@(-19.640604367521664, -42.29003598469333).
# Optimize CC around PointVertex[140456911143248]@(-19.36813998149377, -38.31074432858305).
# Optimize CC around PointVertex[140456911603024]@(8.60921168602628, -13.632087561082482).
# Optimize CC around PointVertex[140456911165712]@(-16.160127608375095, -40.32018001397476).
# Optimize CC around PointVertex[140456911143760]@(-10.165274275779723, -38.70721828824649).
# Optimize CC around PointVertex[140456911145808]@(-15.830689480647122, -36.30492125737158).
# Optimize CC around PointVertex[140456911097616]@(-26.59378893857831, -53.25885199857726).
# Optimize CC around PointVertex[140456911145424]@(-22.400111183932182, -36.22004477255734).
# Optimize CC around PointVertex[140456911135632]@(-19.1149006060043, -34.25382315849244).
# Connecting 2 cycles
# Trying to connect greedily
# 2 cycles remaining
# Computing PCST
# PCST Mip with 2 nodes.
# Values: [14753.500205207829, 1312.295069983517]
# Selected 1 cycles.
# Connecting PCST via DFS
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-7bddbb3eaf18> in <module>
#       2
#       3 alg = MeshAlgorithm()
# ----> 4 tour = alg(instance)
#       5
#
# ~/Repositories/grid_warping/optimizer/solver_selection/abstract_solver.py in __call__(self, pi)
#      26         print("Converting polygon instance to grid instance...")
#      27         grid_instance = self.problem_converter(pi)
# ---> 28         grid_tour = self.grid_solver(grid_instance)
#      29         print("Done. Converting to tour.")
#      30         solution = Solution(convert_tour_to_list(grid_tour))
#
# ~/Repositories/grid_warping/optimizer/grid_solver/grid_solver.py in __call__(self, instance)
#      58         cc = create_cycle_solution(instance.graph, cc)
#      59         tour = connect_cycles_via_pcst(instance, cc)
# ---> 60         cc = create_cycle_solution(instance.graph, tour)
#      61         assert len(cc)==1
#      62         tour = self.tour_optimizer.optimize(instance, tour.to_fractional_solution())
#
# ~/Repositories/grid_warping/optimizer/grid_solver/grid_solution/cycle_solution.py in create_cycle_solution(graph, fractional_solution)
#     321     It will not repeat vertices. You have to close the cycle_cover by yourself.
#     322     """
# --> 323     remaining_passages = VertexPassageSet(graph, fractional_solution)
#     324     cycles = []
#     325     assert are_all_passages_between_neighbors(graph, fractional_solution)
#
# ~/Repositories/grid_warping/optimizer/grid_solver/grid_solution/cycle_solution.py in __init__(self, graph, fractional_solution, eps)
#     248         self.graph = graph
#     249         self._counts = dict()
# --> 250         for vp, x in fractional_solution:
#     251             n = round(x)
#     252             if abs(n - x) > eps:
#
# ~/Repositories/grid_warping/optimizer/grid_solver/grid_instance/point.py in __getitem__(self, item)
#      38         elif item == 1 or item == "y":
#      39             return self.y
# ---> 40         raise KeyError(f"Bad access: {item}")
#      41
#      42     def __str__(self):
#
# KeyError: 'Bad access: 2'

# %%
from pcpptc.plot import plot_solution

ax = setup_plot()
plot_polygon_instance(ax, instance)
plot_solution(ax, tour)
plt.show()
