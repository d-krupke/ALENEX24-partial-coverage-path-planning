# %%
from pcpptc import PolygonInstance
from pcpptc.instance_converter import RotatingRegularSquare, RotatingRegularHexagonal
from pcpptc.instance_converter.dmsh import DmshGrid

from pcpptc.plot import setup_plot, plot_polygon_instance
import matplotlib.pyplot as plt

# %%
from pcpptc.plot.intermediate import plot_graph

pi = PolygonInstance.from_json(file_path="./01b_instance.json")
pi.expensive_areas = []
ax = setup_plot()
plot_polygon_instance(ax, pi, plot_valuable_areas=False)
plt.show()

# %%
figsize = (3.5, 3.5)

# %%
t = RotatingRegularSquare(full_coverage=True, point_based=False)
gi1 = t(pi)

# %%
ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi)
plot_graph(ax, gi1.graph, marker=".", vertex_color="black", edge_color="black")
plt.tight_layout()
plt.savefig("02a_square_grid.pdf")
plt.show()

# %%
t = RotatingRegularHexagonal(full_coverage=True, point_based=False)
gi2 = t(pi)

# %%
ax = setup_plot(figsize=figsize)
plot_polygon_instance(ax, pi)
plot_graph(ax, gi2.graph, marker=".", vertex_color="black", edge_color="black")
plt.tight_layout()
plt.savefig("02b_hex_grid.pdf")
plt.show()

# %%
# TODO: Mesh
t = DmshGrid(full_coverage=True, point_based=False, buffer=0.1, simplification=0.1)
gi3 = t(pi)
# Out:
# Optimize grid with CVT-full

# %%
ax = setup_plot(figsize=figsize)
# ax = setup_plot()
plot_polygon_instance(ax, pi)
plot_graph(ax, gi3.graph, marker=".", vertex_color="black", edge_color="black")
plt.tight_layout()
plt.savefig("02c_mesh_grid.pdf")
plt.show()

# %%
from optimizer.instance_converter.dmsh import GmshGrid

# TODO: Mesh
t = GmshGrid(
    full_coverage=True,
    point_based=False,
    buffer=0.1,
    simplification=0.1,
    quad=True,
    alg=8,
)
gi4 = t(pi)
# Out:
# using gmesh with Frontal-Delaunay for Quads
# Good options are 1, 4, and 9.

# %%
ax = setup_plot(figsize=figsize)
# ax = setup_plot()
plot_polygon_instance(ax, pi)
plot_graph(ax, gi4.graph, marker=".", vertex_color="black", edge_color="black")
plt.tight_layout()
plt.savefig("02d_gmsh_bad.pdf")
plt.show()

# %%
# TODO: Mesh
t = GmshGrid(
    full_coverage=True,
    point_based=False,
    buffer=0.1,
    simplification=0.1,
    alg=1,
    opt_method="",
)
gi5 = t(pi)
# Out:
# using gmesh with MeshAdapt
# Good options are 1, 4, and 9.

# %%
ax = setup_plot(figsize=figsize)
# ax = setup_plot()
plot_polygon_instance(ax, pi)
plot_graph(ax, gi5.graph, marker=".", vertex_color="black", edge_color="black")
plt.tight_layout()
plt.savefig("02e_gmsh_bad.pdf")
plt.show()

# %%
# TODO: Mesh
for i in range(1, 10):
    print(i)
    t = GmshGrid(
        full_coverage=True,
        point_based=False,
        buffer=0.1,
        simplification=0.1,
        alg=i,
        scale=1,
    )
    gi6 = t(pi)

    # %%

    ax = setup_plot(figsize=figsize)
    # ax = setup_plot()
    plot_polygon_instance(ax, pi)
    plot_graph(ax, gi6.graph, marker=".", vertex_color="black", edge_color="black")
    plt.tight_layout()
    plt.show()
# Out:
# 1
# using gmesh with MeshAdapt
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 2
# using gmesh with Automatic
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 3
# using gmesh with Initial mesh only
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# /home/ANONYMOUS_USER/anaconda3/envs/turncost/lib/python3.7/site-packages/meshplex/_mesh.py:246: RuntimeWarning: invalid value encountered in true_divide
#   self._cv_centroids = (integral_p.T / cv).T
# 4
# using gmesh with undefined
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 5
# using gmesh with Delaunay
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 6
# using gmesh with Frontal-Delaunay
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 7
# using gmesh with BAMG
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 8
# using gmesh with Frontal-Delaunay for Quads
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 9
# using gmesh with Packing of Parallelograms
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full

# %%
# TODO: Mesh
for i in range(1, 10):
    print(i)
    t = GmshGrid(
        full_coverage=True,
        point_based=False,
        buffer=0.1,
        simplification=0.1,
        alg=i,
        scale=1,
        opt_method="",
    )
    gi6 = t(pi)

    # %%

    ax = setup_plot(figsize=figsize)
    # ax = setup_plot()
    plot_polygon_instance(ax, pi)
    plot_graph(ax, gi6.graph, marker=".", vertex_color="black", edge_color="black")
    plt.tight_layout()
    plt.show()
# Out:
# 1
# using gmesh with MeshAdapt
# Good options are 1, 4, and 9.
# 2
# using gmesh with Automatic
# Good options are 1, 4, and 9.
# 3
# using gmesh with Initial mesh only
# Good options are 1, 4, and 9.
# 4
# using gmesh with undefined
# Good options are 1, 4, and 9.
# 5
# using gmesh with Delaunay
# Good options are 1, 4, and 9.
# 6
# using gmesh with Frontal-Delaunay
# Good options are 1, 4, and 9.
# 7
# using gmesh with BAMG
# Good options are 1, 4, and 9.
# 8
# using gmesh with Frontal-Delaunay for Quads
# Good options are 1, 4, and 9.
# 9
# using gmesh with Packing of Parallelograms
# Good options are 1, 4, and 9.

# %%
# TODO: Mesh
for i in range(1, 10):
    print(i)
    t = GmshGrid(
        full_coverage=True,
        point_based=False,
        buffer=0.1,
        simplification=0.1,
        alg=i,
        scale=1,
        quad=True,
        hard_corners=True,
    )
    gi6 = t(pi)

    # %%

    ax = setup_plot(figsize=figsize)
    # ax = setup_plot()
    plot_polygon_instance(ax, pi)
    plot_graph(ax, gi6.graph, marker=".", vertex_color="black", edge_color="black")
    plt.tight_layout()
    plt.show()
# Out:
# 1
# using gmesh with MeshAdapt
# Good options are 1, 4, and 9.
# 2
# using gmesh with Automatic
# Good options are 1, 4, and 9.
# 3
# using gmesh with Initial mesh only
# Good options are 1, 4, and 9.
# 4
# using gmesh with undefined
# Good options are 1, 4, and 9.
# 5
# using gmesh with Delaunay
# Good options are 1, 4, and 9.
# 6
# using gmesh with Frontal-Delaunay
# Good options are 1, 4, and 9.
# 7
# using gmesh with BAMG
# Good options are 1, 4, and 9.
# 8
# using gmesh with Frontal-Delaunay for Quads
# Good options are 1, 4, and 9.
# 9
# using gmesh with Packing of Parallelograms
# Good options are 1, 4, and 9.

# %%
# TODO: Mesh
for i in range(1, 10):
    print(i)
    t = GmshGrid(
        full_coverage=True,
        point_based=False,
        buffer=0.1,
        simplification=0.1,
        alg=i,
        scale=1,
        hard_corners=True,
    )
    gi6 = t(pi)

    # %%

    ax = setup_plot(figsize=figsize)
    # ax = setup_plot()
    plot_polygon_instance(ax, pi)
    plot_graph(ax, gi6.graph, marker=".", vertex_color="black", edge_color="black")
    plt.tight_layout()
    plt.show()
# Out:
# 1
# using gmesh with MeshAdapt
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 2
# using gmesh with Automatic
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 3
# using gmesh with Initial mesh only
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 4
# using gmesh with undefined
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 5
# using gmesh with Delaunay
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 6
# using gmesh with Frontal-Delaunay
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 7
# using gmesh with BAMG
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 8
# using gmesh with Frontal-Delaunay for Quads
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
# 9
# using gmesh with Packing of Parallelograms
# Good options are 1, 4, and 9.
# Optimize grid with CVT-full
